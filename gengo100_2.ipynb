# %% [markdown]
# <a href="https://colab.research.google.com/github/yydevelop/kaggle/blob/main/gengo100_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://nlp100.github.io/data/popular-names.txt
# Out:
# --2021-10-02 06:46:02--  https://nlp100.github.io/data/popular-names.txt
# Resolving nlp100.github.io (nlp100.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to nlp100.github.io (nlp100.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55026 (54K) [text/plain]
# Saving to: ‘popular-names.txt’
#
# popular-names.txt   100%[===================>]  53.74K  --.-KB/s    in 0.001s
#
# 2021-10-02 06:46:02 (73.3 MB/s) - ‘popular-names.txt’ saved [55026/55026]

# %% [markdown]
# 10. 行数のカウント

# %%
# !wc -l popular-names.txt
# Out:
# 2780 popular-names.txt

# %% [markdown]
# 12. 1列目をcol1.txtに，2列目をcol2.txtに保存

# %%
# !cut -f1 popular-names.txt > col1.txt
# !cut -f2 popular-names.txt > col2.txt

# %%
# !paste col1.txt col2.txt > 13.txt

# %%
# !head -5 popular-names.txt
# Out:
# Mary	F	7065	1880
# Anna	F	2604	1880
# Emma	F	2003	1880
# Elizabeth	F	1939	1880
# Minnie	F	1746	1880

# %%
# !tail -5 popular-names.txt
# Out:
# Benjamin	M	13381	2018
# Elijah	M	12886	2018
# Lucas	M	12585	2018
# Mason	M	12435	2018
# Logan	M	12352	2018

# %%
# !split -l5 popular-names.txt

# %%
# !ls -l
# Out:
# total 2344
# -rw-r--r-- 1 root root 25078 Oct  2 06:49 13.txt
# -rw-r--r-- 1 root root 19518 Oct  2 06:48 col1.txt
# -rw-r--r-- 1 root root  5560 Oct  2 06:48 col2.txt
# drwx------ 5 root root  4096 Oct  2 06:44 drive
# -rw-r--r-- 1 root root 55026 Dec 25  2020 popular-names.txt
# drwxr-xr-x 1 root root  4096 Sep 30 17:12 sample_data
# -rw-r--r-- 1 root root    92 Oct  2 06:50 xaa
# -rw-r--r-- 1 root root    92 Oct  2 06:50 xab
# -rw-r--r-- 1 root root    94 Oct  2 06:50 xac
# -rw-r--r-- 1 root root    93 Oct  2 06:50 xad
# -rw-r--r-- 1 root root    94 Oct  2 06:50 xae
# -rw-r--r-- 1 root root    90 Oct  2 06:50 xaf
# -rw-r--r-- 1 root root    94 Oct  2 06:50 xag
# -rw-r--r-- 1 root root    93 Oct  2 06:50 xah
# -rw-r--r-- 1 root root    92 Oct  2 06:50 xai
# -rw-r--r-- 1 root root    92 Oct  2 06:50 xaj
# -rw-r--r-- 1 root root    94 Oct  2 06:50 xak
# -rw-r--r-- 1 root root    93 Oct  2 06:50 xal
# -rw-r--r-- 1 root root    92 Oct  2 06:50 xam
# ...

# %%
